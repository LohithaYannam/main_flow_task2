# %%
import pandas as pd

# %%
#load CSV file into a pandas dataframe
data=pd.read_csv("01.Data Cleaning and Preprocessing.csv")
data.head(10)
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
# 5     1-08:00    14.23    15.350      85.518  1171.604      198.538
# 6     1-09:00    13.49    13.700      98.186  1243.688      116.275
# 7    31-06:00    22.65    14.100      91.887  1307.852      288.989
# 8    31-07:00    22.50    14.233      97.249  1346.900      330.325
# 9    31-08:00    24.70    13.850      96.208  1334.892      362.511
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# ...

# %%
print(data)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#filtering data based on conditions
data.loc[data['UCZAA']<1.523]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 5       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 6       1-09:00    13.49    13.700      98.186  1243.688      116.275
# 7      31-06:00    22.65    14.100      91.887  1307.852      288.989
# 8      31-07:00    22.50    14.233      97.249  1346.900      330.325
# ..          ...      ...       ...         ...       ...          ...
# 313    31-11:00    26.62    15.467      84.447  1334.255      386.971
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data.loc[(data["BlowFlow"]<1243.688) &(data["UCZAA"]<1.434)]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 28      1-03:00    21.10    12.667      86.083  1182.201      295.825
# 36      1-11:00    12.81    10.942     114.567  1241.142      215.485
# 37      1-12:00    14.53    10.833      93.121  1202.818      339.119
# 38      1-13:00    18.45    12.917      84.483  1175.728      391.599
# 39      1-14:00    24.30    13.917      87.835  1190.889      390.140
# 40      1-15:00    27.10    13.558      83.117  1175.417      289.256
# 41      1-16:00    24.70    14.142      80.809  1171.734      104.205
# 42      1-17:00    22.30    14.500      84.884  1189.789      133.151
# 44      1-19:00    23.00    14.008      80.199  1188.278      194.959
# 59      2-10:00    15.73    14.683      84.488  1240.563      212.441
# 62      2-13:00    23.50    14.542      76.570  1239.153      311.633
# 67      2-18:00    21.80    15.467      79.303  1228.541      204.661
# ...

# %%
#handling missing values
data.dropna()
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7      31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9      31-08:00    24.70    13.850      96.208  1334.892      362.511
# ..          ...      ...       ...         ...       ...          ...
# 312    31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data.loc[:,['BlowFlow','UCZAA']].dropna()
# Out:
#      BlowFlow  UCZAA
# 0    1177.607  1.443
# 1    1328.360  1.549
# 2    1329.407  1.600
# 3    1334.877  1.604
# 5    1171.604  1.436
# ..        ...    ...
# 319  1178.252  1.523
# 320  1184.119  1.451
# 321  1188.517  1.457
# 322  1192.879  1.523
# 323  1186.342  1.474
#
# [284 rows x 2 columns]

# %%
data.fillna("MISSING")
# Out:
#     Observation  Y-Kappa ChipRate BF-CMratio  BlowFlow ChipLevel4   \
# 0      31-00:00    23.10    16.52    121.717  1177.607     169.805
# 1      31-01:00    27.60    16.81     79.022   1328.36     341.327
# 2      31-02:00    23.19   16.709     79.562  1329.407     239.161
# 3      31-03:00    23.60   16.478     81.011  1334.877     213.527
# 4      31-04:00    22.90   15.618     93.244  1334.168     243.131
# ..          ...      ...      ...        ...       ...         ...
# 319    10-16:00    23.75   12.667      93.45  1178.252     276.955
# 320     9-19:00    19.80   12.558     94.352  1184.119     297.071
# 321     9-20:00    23.01    12.55     90.842  1188.517     289.826
# 322     9-21:00    24.32   13.083      88.91  1192.879     318.006
# 323     9-22:00    25.75   13.417     85.451  1186.342     248.312
#
#     T-upperExt-2  T-lowerExt-2      UCZAA WhiteFlow-4   ... SteamFlow-4   \
# 0         358.282        329.545    1.443      599.253  ...       67.122
# ...

# %%
data['UCZAA'].fillna(1.656)
# Out:
# 0      1.443
# 1      1.549
# 2      1.600
# 3      1.604
# 4      1.656
#        ...
# 319    1.523
# 320    1.451
# 321    1.457
# 322    1.523
# 323    1.474
# Name: UCZAA, Length: 324, dtype: float64

# %%
data.loc[:,['BlowFlow','UCZAA']].fillna(2.444)
# Out:
#      BlowFlow  UCZAA
# 0    1177.607  1.443
# 1    1328.360  1.549
# 2    1329.407  1.600
# 3    1334.877  1.604
# 4    1334.168  2.444
# ..        ...    ...
# 319  1178.252  1.523
# 320  1184.119  1.451
# 321  1188.517  1.457
# 322  1192.879  1.523
# 323  1186.342  1.474
#
# [324 rows x 2 columns]

# %%
#calculating summary statistics
data.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
#summary statistics that describe numeric values
data.sum()
# Out:
# Observation        31-00:0031-01:0031-02:0031-03:0031-04:001-08:0...
# Y-Kappa                                                      6685.86
# ChipRate                                                    4576.992
# BF-CMratio                                                 26851.588
# BlowFlow                                                  381253.985
# ChipLevel4                                                 83387.128
# T-upperExt-2                                              114923.183
# T-lowerExt-2                                              104334.498
# UCZAA                                                        446.111
# WhiteFlow-4                                                191129.52
# AAWhiteSt-4                                                 1062.291
# AA-Wood-4                                                   5760.991
# ChipMoisture-4                                             15110.576
# SteamFlow-4                                                21533.856
# ...

# %%
data.max()
# Out:
# Observation         9-23:00
# Y-Kappa                27.6
# ChipRate             16.958
# BF-CMratio          121.717
# BlowFlow            1351.24
# ChipLevel4          419.014
# T-upperExt-2        399.135
# T-lowerExt-2        337.012
# UCZAA                 1.747
# WhiteFlow-4         731.394
# AAWhiteSt-4            6.34
# AA-Wood-4            19.582
# ChipMoisture-4       50.658
# SteamFlow-4          76.147
# Lower-HeatT-3       333.854
# Upper-HeatT-3       311.146
# ChipMass-4          189.268
# WeakLiquorF        1226.277
# BlackFlow-2        1395.767
# WeakWashF           715.715
# SteamHeatF-3         63.332
# T-Top-Chips-4       254.122
# SulphidityL-4         32.84
# dtype: object
